# %%
import pandas as pd

# 1. Charger les données brutes
df_train = pd.read_csv('data/raw/train.csv')

# 2. Inspecter la structure globale
print("--- 5 premières lignes ---")
display(df_train.head()) 

print("\n--- Informations sur les colonnes ---")
df_train.info()
# Out:
# --- 5 premières lignes ---
#    Class Index                                              Title  \
# 0            3  Wall St. Bears Claw Back Into the Black (Reuters)
# 1            3  Carlyle Looks Toward Commercial Aerospace (Reu...
# 2            3    Oil and Economy Cloud Stocks' Outlook (Reuters)
# 3            3  Iraq Halts Oil Exports from Main Southern Pipe...
# 4            3  Oil prices soar to all-time record, posing new...
#
#                                          Description
# 0  Reuters - Short-sellers, Wall Street's dwindli...
# 1  Reuters - Private investment firm Carlyle Grou...
# 2  Reuters - Soaring crude prices plus worries\ab...
# 3  Reuters - Authorities have halted oil export\f...
# 4  AFP - Tearaway world oil prices, toppling reco...
# --- Informations sur les colonnes ---
# <class 'pandas.DataFrame'>
# RangeIndex: 120000 entries, 0 to 119999
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Class Index  120000 non-null  int64
#  1   Title        120000 non-null  str
#  2   Description  120000 non-null  str
# dtypes: int64(1), str(2)
# memory usage: 2.7 MB

# %%
# 3. Vérifier la qualité des données (valeurs manquantes et doublons)
print("\n--- Valeurs manquantes par colonne ---")
print(df_train.isnull().sum())

print("\n--- Nombre de lignes en double ---")
print(df_train.duplicated().sum())

# (Optionnel) Pour nettoyer les doublons et les lignes vides :
df_train_clean = df_train.dropna().drop_duplicates()
# Out:
# --- Valeurs manquantes par colonne ---
# Class Index    0
# Title          0
# Description    0
# dtype: int64
#
# --- Nombre de lignes en double ---
# 0

# %%
# 4. Analyser la distribution des catégories
# Attention : remplace 'Class Index' par le vrai nom de la colonne qui contient tes labels !
print("\n--- Répartition des articles par catégorie ---")
print(df_train_clean['Class Index'].value_counts())
# Out:
# --- Répartition des articles par catégorie ---
# Class Index
# 3    30000
# 4    30000
# 2    30000
# 1    30000
# Name: count, dtype: int64

# %%
# 1. Créer un dictionnaire pour mapper les chiffres aux vrais noms de catégories (AG News)
label_mapping = {
    1: 'World', 
    2: 'Sports', 
    3: 'Business', 
    4: 'Sci/Tech'
}

# Appliquer le mapping pour créer une nouvelle colonne 'Category'
df_train['Category'] = df_train['Class Index'].map(label_mapping)

# %%
# 2. Combiner le Titre et la Description en une seule colonne 'Text'
# (Maroine aura ainsi un seul grand texte à nettoyer)
df_train['Text'] = df_train['Title'] + " " + df_train['Description']

# 3. Sélectionner uniquement les colonnes finales dont l'équipe a besoin
df_final = df_train[['Text', 'Category']]

# Vérifier à quoi ressemble notre fichier final
print("--- Aperçu du jeu de données final ---")
display(df_final.head())

# 4. SAUVEGARDER LE FICHIER dans le dossier des données traitées
# C'est CE fichier que tu vas livrer à ton équipe !
df_final.to_csv('data/processed/train_clean.csv', index=False)
# Out:
# --- Aperçu du jeu de données final ---
#                                                 Text  Category
# 0  Wall St. Bears Claw Back Into the Black (Reute...  Business
# 1  Carlyle Looks Toward Commercial Aerospace (Reu...  Business
# 2  Oil and Economy Cloud Stocks' Outlook (Reuters...  Business
# 3  Iraq Halts Oil Exports from Main Southern Pipe...  Business
# 4  Oil prices soar to all-time record, posing new...  Business

# %%
import pandas as pd

# 1. Charger le fichier de test brut
df_test = pd.read_csv('data/raw/test.csv')

# 2. Définir le mapping des catégories (si tu es dans une nouvelle cellule)
label_mapping = {
    1: 'World', 
    2: 'Sports', 
    3: 'Business', 
    4: 'Sci/Tech'
}

# 3. Appliquer les transformations
# Création de la colonne Category avec les vrais noms
df_test['Category'] = df_test['Class Index'].map(label_mapping)

# Fusion du Titre et de la Description
df_test['Text'] = df_test['Title'] + " " + df_test['Description']

# 4. Conserver uniquement les colonnes utiles
df_test_final = df_test[['Text', 'Category']]

# 5. SAUVEGARDER LE FICHIER de test propre
df_test_final.to_csv('data/processed/test_clean.csv', index=False)

print("Le fichier test_clean.csv a été créé et sauvegardé avec succès ! ")
# Out:
# Le fichier test_clean.csv a été créé et sauvegardé avec succès !

# %%
import pandas as pd

df_bbc = pd.read_csv('data/raw/bbc-text.csv')

# Afficher les premières lignes pour vérifier
print("Aperçu des données BBC News :")
print(df_bbc.head())

# Vérifier les catégories disponibles
print("\nCatégories dans BBC News :")
print(df_bbc['category'].unique())
# Out:
# Aperçu des données BBC News :
#         category                                               text
# 0           tech  tv future in the hands of viewers with home th...
# 1       business  worldcom boss  left books alone  former worldc...
# 2          sport  tigers wary of farrell  gamble  leicester say ...
# 3          sport  yeading face newcastle in fa cup premiership s...
# 4  entertainment  ocean s twelve raids box office ocean s twelve...
#
# Catégories dans BBC News :
# <StringArray>
# ['tech', 'business', 'sport', 'entertainment', 'politics']
# Length: 5, dtype: str

# %%
from sklearn.model_selection import train_test_split

# Charger le jeu de données BBC depuis ton dossier raw
df_bbc = pd.read_csv('data/raw/bbc-text.csv')

# Le dictionnaire de traduction (Option A : 4 catégories)
bbc_mapping = {
    'business': 'Business',
    'sport': 'Sports',
    'tech': 'Sci/Tech',
    'politics': 'World'
    # 'entertainment' est volontairement ignoré
}

# %%
# Appliquer le mapping et supprimer les articles 'entertainment' (devenus NaN)
df_bbc['Category'] = df_bbc['category'].map(bbc_mapping)
df_bbc_clean = df_bbc.dropna(subset=['Category']).copy()

# %%
# Renommer la colonne pour matcher AG News et garder les bonnes colonnes
df_bbc_clean = df_bbc_clean.rename(columns={'text': 'Text'})
df_bbc_final = df_bbc_clean[['Text', 'Category']]

# %%
# Séparer les données de la BBC en Train (80%) et Test (20%)
bbc_train, bbc_test = train_test_split(
    df_bbc_final, 
    test_size=0.2, 
    random_state=42, 
    stratify=df_bbc_final['Category']
)

# %%
#  Charger les fichiers AG News de base
df_ag_train = pd.read_csv('data/processed/train_clean.csv')
df_ag_test = pd.read_csv('data/processed/test_clean.csv')

# %%
#  🔗 FUSIONNER ET 🔀 MÉLANGER
df_train_augmented = pd.concat([df_ag_train, bbc_train], ignore_index=True).sample(frac=1, random_state=42).reset_index(drop=True)
df_test_augmented = pd.concat([df_ag_test, bbc_test], ignore_index=True).sample(frac=1, random_state=42).reset_index(drop=True)

# %%
# SAUVEGARDER les fichiers finaux
df_train_augmented.to_csv('data/processed/train_augmented_clean.csv', index=False)
df_test_augmented.to_csv('data/processed/test_augmented_clean.csv', index=False)

print("✅ Succès ! Les fichiers Train et Test ont été augmentés tout en conservant les 4 catégories initiales.")
# Out:
# ✅ Succès ! Les fichiers Train et Test ont été augmentés tout en conservant les 4 catégories initiales.
